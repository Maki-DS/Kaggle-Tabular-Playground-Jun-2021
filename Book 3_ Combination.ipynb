# %%
import pandas as pd

# %%
xgb = pd.read_csv('/content/submission_NN_final (1).csv', sep=',', header=0)
nn = pd.read_csv('/content/submission_XGB_final (1).csv', sep=',', header=0)

df = pd.concat([xgb, nn])
final = df.groupby(level=0).mean()
final
# Out:
#            id   Class_1   Class_2  ...   Class_7   Class_8   Class_9
# 0      200000  0.056742  0.386682  ...  0.025724  0.052517  0.122102
# 1      200001  0.045914  0.092592  ...  0.090530  0.288416  0.117903
# 2      200002  0.024435  0.035929  ...  0.032784  0.118295  0.062275
# 3      200003  0.049017  0.105290  ...  0.080027  0.240865  0.164636
# 4      200004  0.043332  0.107021  ...  0.062484  0.222954  0.134747
# ...       ...       ...       ...  ...       ...       ...       ...
# 99995  299995  0.067552  0.379189  ...  0.038253  0.078427  0.140407
# 99996  299996  0.058246  0.281335  ...  0.047065  0.118244  0.152476
# 99997  299997  0.072565  0.234000  ...  0.049557  0.127345  0.153325
# 99998  299998  0.033757  0.027126  ...  0.083131  0.343405  0.085940
# 99999  299999  0.048372  0.072743  ...  0.082370  0.244338  0.137621
#
# [100000 rows x 10 columns]

# %%
final.to_csv('Submission.csv',index=False)
